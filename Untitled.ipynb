# %%
import pandas as pd

# %%
gameCount = 0
events = []
currPitcher = []

with open("2010seve/2019WAS.EVN", 'r') as data:
    for line in data:
        if line.strip().split(',')[0] == 'id':
            gameCount += 1
        elif line.strip().split(',')[-3]
# Out:
# ['id,WAS201903280']
# ['version,2']
# ['info,visteam,NYN']
# ['info,hometeam,WAS']
# ['info,site,WAS11']
# ['info,date,2019/03/28']
# ['info,number,0']
# ['info,starttime,1:07PM']
# ['info,daynight,day']
# ['info,usedh,false']
# ['info,umphome,millb901']
# ['info,ump1b,eddid901']
# ['info,ump2b,torrc901']
# ['info,ump3b,conrc901']
# ['info,howscored,park']
# ['info,pitches,pitches']
# ['info,oscorer,tritb701']
# ['info,temp,56']
# ['info,winddir,rtol']
# ['info,windspeed,3']
# ['info,fieldcond,unknown']
# ['info,precip,unknown']
# ['info,sky,cloudy']
# ['info,timeofgame,164']
# ['info,attendance,42263']
# ['info,wp,degrj001']
# ['info,lp,schem001']
# ['info,save,diaze006']
# ['start,nimmb001,"Brandon', 'Nimmo",0,1,7']
# ['start,alonp001,"Pete', 'Alonso",0,2,3']
# ['start,canor001,"Robinson', 'Cano",0,3,4']
# ['start,confm001,"Michael', 'Conforto",0,4,9']
# ['start,ramow001,"Wilson', 'Ramos",0,5,2']
# ['start,mcnej002,"Jeff', 'McNeil",0,6,5']
# ...
